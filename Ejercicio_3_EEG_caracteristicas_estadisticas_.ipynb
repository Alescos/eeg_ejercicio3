# %% [markdown]
# <a href="https://colab.research.google.com/github/veroggu/eeg_ejercicio3/blob/main/Ejercicio_3_EEG_caracteristicas_estadisticas_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Contexto:**  De manera cuantitativa es posible caracterizar la señal EEG por medio de un análisis en el tiempo. Para ello en la literatura se reportan algunos modelos matemáticos basados en cálculos lineales y no lineales, que cuentan con aplicaciones en diversos campos.
#
# ### **Objetivo:** Caracterizar una base de datos EEG mediante análisis temporal
#
# ### **Google forms:** https://forms.gle/EGve36Vgvdd6SokK9

# %% [markdown]
# ## 1).   Python

# %%
#Instalación de librería MNE

# !pip install -U https://github.com/mne-tools/mne-python/archive/master.zip
# Out:
# Usage:
#   pip3 install [options] <requirement specifier> [package-index-options] ...
#   pip3 install [options] -r <requirements file> [package-index-options] ...
#   pip3 install [options] [-e] <vcs project url> ...
#   pip3 install [options] [-e] <local project path> ...
#   pip3 install [options] <archive url/path> ...
#
# no such option: ---

# %%
#Importación de librerías

import mne 
import numpy as np
import pandas as pd
import scipy.io as sio
import matplotlib.pyplot as plt

# %% [markdown]
# **-> -> -> Active la conexión con Drive (de manera manual) y cree un acceso directo de los datos en su unidad <- <- <-**

# %%
# Descomprima los archivos con el siguiente código

# !pip install unrar
# !unrar x 'data_set.rar'  #Lea la documentación de 'unrar' para distinguir la utilidad de 'x'

# %%
input_data = '--'

# %% [markdown]
# ## 1.1) MNE
#
# **-> -> -> Implemente la función adecuada para importar los archivos EDF según la información del siguiente link: <- <- <-** https://mne.tools/0.17/manual/io.html

# %%
#Lea los archivos con la librería MNE

#-->Para un paciente

file = "--"   #Tenga en cuenta estar ubicado en la carpeta donde se encuentran los archivos
data = mne.io.read_--(file)

#A partir de "data"
raw_data = data.get_data()

# Metadata (a partir de "data"):
info = --
channels = --
frec_muestreo = --

#Graficación
plt.plot(raw_data[0,:3000],'-')
plt.title('Paciente #)
plt.show()

# %%
#Ejecute la siguiente celda de código

# -->Para todos los pacientes

files = []
raw_data = []

for i in np.arange(4):
    file = "eeg"+str(i+2)+".edf"
    files.append(file)

for i in files:
  data = mne.io.read_raw_edf(i)
  raw = data.get_data()
  raw_data.append(raw)

# %%
#Señal de cada paciente (5 en total)

for i in np.arange(--):
  plt.plot(raw_data[i][0,:3000],'-')
  plt.title(files[i])
  plt.xlabel('--')
  plt.ylabel('--')
  plt.show()

# %%
#Todos los canales para un paciente

raw = mne.io.RawArray(raw_data[-], info)
fig = raw.plot(start=10,duration=3,scalings={'eeg':'auto'},n_channels=int(raw._data.shape[0]),show=False)
fig.set_size_inches((25,raw._data.shape[0]))

# %% [markdown]
# ## 1.2) Exploración de los datos

# %% [markdown]
# **->->->Construir un arreglo de un paciente con sus datos EEG y las anotaciones suministradas por uno de los expertos<-<-<-** (Recomentación: Librería Pandas)

# %%
#Importe un archivo con anotaciones (o marcas)

anotaciones_a = pd.--(r'----')
print(anotaciones_a.iloc[:,0])

# %%
# Para un paciente

anotaciones = anotaciones_a.iloc[:6993,0] #Se elige ese número de datos para evitar NaN respecto a las anotaciones A (ver Excel)
paciente1 = raw_data[-][0,:np.size(---)] #Mismo número de datos entre pacientes y anotaciones
paciente = pd.DataFrame({'Paciente#':--,'Anotaciones':--})

# %%
#Exportar DataFrame como un archivo CSV

# %cd /content/drive/My Drive/NeuroCo_Personal
-----

# %% [markdown]
# **->->->Estadística con Python<-<-<-**
# Genere un código para calcular algunos resultados estadísticos con Python teniendo en cuenta las anotaciones suministradas de los pacientes [DISCUSIÓN GRUPO - GENERAL]

# %%
----

# %% [markdown]
# ## 1.3) Características con PyEEG

# %% [markdown]
# **->->->Clone el siguiente repositorio<-<-<-**
# Link: git://github.com/forrestbao/pyeeg
#
# Siga las instrucciones del README del repositorio e instale la librería

# %%
# !git clone --

# %%
# !python setu--

# %% [markdown]
# Calcule al menos dos de las medidas temporales presentes en la librería para un paciente

# %%
paciente1_hurst = pyeeg--
paciente2_entropy = pyegg--

# %% [markdown]
# ## 1.2) Matriz de trabajo
#
# [DISCUSIÓN GRUPAL - GENERAL]

# %% [markdown]
# **->->->cree una matriz que contenga la información de todos los pacientes.<-<-<-** (sugerencia: librería Pandas)

# %%
pacientes = pd.DataFrame({--})

# %% [markdown]
# ## 2).   R

# %% [markdown]
# ##2.1) Instalación
#
# Instale los siguientes paquetes R y RStudio (IDE)

# %% [markdown]
# ### **R**
#
# *   Link: https://cran.r-project.org/bin/windows/base/
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# _________________________________________________________________________
#
# ### **RStudio**
#
# *  Link: https://rstudio.com/products/rstudio/download/
#
# ![image.png](data:image/png;base64,...)
